# %%
import matplotlib.pyplot as plt
import pandas as pd
# !pwd
# %matplotlib inline
# Out:
# /home/tim/src/gkigit.informatik.uni-freiburg.de/tschulte/dimap

# %%
files = [
    'benchmarks/results/feb-05-2018-084907-results.csv',
    'benchmarks/results/feb-09-2018-082423-results.csv',
    'benchmarks/results/feb-09-2018-154759-results.csv',
    'benchmarks/results/feb-12-2018-094100-results.csv',
    'benchmarks/results/mar-21-2018-083349-results.csv',
    'benchmarks/results/mar-26-2018-123427-results.csv',
    'benchmarks/results/apr-06-2018-121125-results.csv'
]

def iter_frames(files):
    for f in files:
        df = pd.read_csv(f)
        yield df.set_index(['Config', 'Domain', 'Problem', 'AgentID'])


def groupings(frames):
    for f in frames:
        g = f.groupby(level=['Config', 'Domain', 'Problem'])[['Solved', 'Time', 'Expansions']]
        g = g.agg({'Solved':'max', 'Time':'mean', 'Expansions':'sum'})
        yield g

dfs = list(iter_frames(files))
gs = list(groupings(dfs))

# %%
g = gs[-1].query('Domain == "productionsite"')
g = g.unstack('Config')
g = g['Time'][['gc-mafs-defrt', 'gc-mafs-defrt-sss']]
g = g * 60.0

g = g.sort_values(by='gc-mafs-defrt')
g = g.iloc[28:48]
g = g[g <= (30.0 * 60.0)].reset_index(drop=True)
g.columns = ['def', 'sss']

g.plot(style=['o-.', '^-', 'x-'], ylim=[-2,(35*60)], xticks=range(20), logy=True)
plt.legend(loc=2)
plt.savefig('productionsite.pdf', dpi=300, bbox_inches='tight', pad_inches=0.0)

# %%
# Coverage per config (summary)
coverage = list()
for i, g in enumerate(gs):
    coverage.append(g['Solved'].groupby(level=['Config', 'Domain']).sum().unstack('Config'))
    print('-'.join(files[i].split('-')[:-2]))
    print(coverage[i], end='\n\n')
# Out:
# benchmarks/results/feb-05-2018
# Config       dmtg-def  dmtg-deft  dmtg-t100  dmtg-t100t  mafs-def  mafs-deft  \
# Domain
# blocksworld       0.0        1.0       16.0        16.0       0.0        0.0
# depot             2.0        2.0        1.0         2.0       0.0        0.0
# driverlog        15.0       15.0       20.0        20.0      15.0       17.0
# elevators        12.0       14.0       17.0        15.0      15.0       13.0
# logistics        15.0       16.0       20.0        17.0      12.0       14.0
# rovers            9.0       10.0       20.0        20.0      18.0       18.0
# satellites        9.0       10.0       20.0        20.0      17.0       20.0
# sokoban           9.0        9.0        8.0        10.0       7.0        8.0
# taxi             14.0       15.0       12.0        12.0       2.0        2.0
# wireless          2.0        2.0        2.0         2.0       1.0        1.0
# woodworking       7.0        6.0       13.0        13.0       6.0        4.0
# zenotravel       17.0       18.0       18.0        20.0      14.0       16.0
#
# Config       mafs-t100  mafs-t100t
# Domain
# blocksworld       18.0        18.0
# depot              0.0         0.0
# driverlog         20.0        20.0
# elevators         13.0        14.0
# logistics         15.0        14.0
# rovers            20.0        20.0
# satellites        20.0        20.0
# sokoban            9.0         7.0
# taxi               2.0         2.0
# wireless           0.0         1.0
# woodworking        6.0        11.0
# zenotravel        20.0        20.0
#
# benchmarks/results/feb-09-2018
# Config       dmtg-deft  dmtg-t100t  mafs-deft  mafs-t100t
# Domain
# blocksworld        1.0        18.0        0.0        16.0
# depot              2.0         2.0        0.0         0.0
# driverlog         16.0        20.0       15.0        16.0
# elevators          8.0        15.0       15.0        15.0
# logistics         15.0        16.0       15.0        17.0
# rovers             8.0        20.0       17.0        17.0
# satellites        11.0        20.0       19.0        20.0
# sokoban            6.0        12.0        9.0         7.0
# taxi              16.0        16.0        2.0         2.0
# wireless           1.0         1.0        0.0         0.0
# woodworking        9.0        15.0        3.0         7.0
# zenotravel        19.0        20.0       15.0        20.0
#
# benchmarks/results/feb-09-2018
# Config       dmtg-deft  dmtg-t100t  mafs-deft  mafs-t100t
# Domain
# blocksworld        0.0        17.0        0.0        16.0
# depot              2.0         2.0        0.0         0.0
# driverlog         16.0        20.0       14.0        14.0
# elevators         15.0        15.0       17.0        15.0
# logistics         16.0        17.0       12.0        15.0
# rovers             8.0        20.0       18.0        18.0
# satellites        10.0        20.0       20.0        20.0
# sokoban            9.0         9.0        7.0         7.0
# taxi              14.0        15.0        2.0         2.0
# wireless           1.0         2.0        1.0         1.0
# woodworking        7.0        13.0        2.0         7.0
# zenotravel        19.0        20.0       16.0        19.0
#
# benchmarks/results/feb-12-2018
# Config       dmtg-deft  dmtg-t100t  mafs-deft  mafs-t100t
# Domain
# blocksworld        0.0        19.0        0.0        18.0
# depot              2.0         2.0        1.0         0.0
# driverlog         15.0        20.0       14.0        16.0
# elevators         14.0        13.0       16.0        15.0
# logistics         18.0        18.0       13.0        16.0
# rovers             9.0        20.0       17.0        19.0
# satellites        10.0        20.0       19.0        20.0
# sokoban            7.0         7.0        6.0         9.0
# taxi              15.0        17.0        2.0         2.0
# wireless           2.0         2.0        1.0         0.0
# woodworking        7.0        14.0        3.0        10.0
# zenotravel        19.0        20.0       14.0        19.0
#
# benchmarks/results/mar-21-2018
# Config          blind-dmtg-deft  blind-dmtg-deft-sss  blind-mafs-defrt  \
# Domain
# blocksworld                 0.0                  0.0               0.0
# depot                       0.0                  0.0               2.0
# driverlog                   6.0                  7.0               7.0
# elevators                   0.0                  0.0               3.0
# logistics                   1.0                  0.0               3.0
# productionsite              0.0                 20.0              20.0
# rovers                      0.0                  0.0              20.0
# satellites                  0.0                  0.0               3.0
# sokoban                     6.0                  7.0               2.0
# taxi                        2.0                  2.0               6.0
# wireless                    0.0                  0.0               0.0
# woodworking                 1.0                  1.0               2.0
# zenotravel                  6.0                  5.0               5.0
#
# Config          blind-mafs-defrt-sss  dmtg-deft  dmtg-deft-sss  gc-dmtg-deft  \
# Domain
# blocksworld                      0.0        1.0            0.0           1.0
# depot                            2.0        1.0            2.0           2.0
# driverlog                        7.0       17.0           16.0          17.0
# elevators                        2.0       13.0           14.0          20.0
# logistics                        3.0       18.0           11.0          17.0
# productionsite                  20.0        0.0           20.0           0.0
# rovers                          20.0        8.0            9.0          12.0
# satellites                       3.0        8.0           10.0          14.0
# sokoban                          0.0        8.0            7.0           6.0
# taxi                             8.0       16.0           17.0          14.0
# wireless                         0.0        2.0            2.0           0.0
# woodworking                      1.0        8.0            1.0           2.0
# zenotravel                       5.0       19.0           14.0          20.0
#
# Config          gc-dmtg-deft-sss  gc-mafs-defrt  gc-mafs-defrt-sss  \
# Domain
# blocksworld                  1.0            1.0                1.0
# depot                        2.0            6.0                4.0
# driverlog                   16.0           17.0               16.0
# elevators                   20.0           20.0               20.0
# logistics                   13.0           18.0               14.0
# productionsite              20.0           12.0               20.0
# rovers                      12.0           19.0               20.0
# satellites                  16.0           20.0               20.0
# sokoban                      6.0            2.0                4.0
# taxi                        13.0           11.0               13.0
# wireless                     0.0            0.0                0.0
# woodworking                  1.0            2.0                1.0
# zenotravel                  16.0           20.0               16.0
#
# Config          mafs-defrt  mafs-defrt-sss
# Domain
# blocksworld            0.0             1.0
# depot                  0.0             0.0
# driverlog             16.0            16.0
# elevators             12.0            14.0
# logistics             17.0            15.0
# productionsite         6.0            20.0
# rovers                20.0            18.0
# satellites            20.0            19.0
# sokoban                7.0             7.0
# taxi                   2.0             2.0
# wireless               2.0             1.0
# woodworking            2.0             1.0
# zenotravel            16.0            14.0
#
# benchmarks/results/mar-26-2018
# Config          blind-mafs-defrt  blind-mafs-defrt-sss  gc-mafs-defrt  \
# Domain
# productionsite               2.0                  49.0           39.0
#
# Config          gc-mafs-defrt-sss  mafs-defrt  mafs-defrt-sss
# Domain
# productionsite               49.0        36.0            48.0
#
# benchmarks/results/apr-06-2018
# Config          blind-mafs-defrt  blind-mafs-defrt-sss  gc-mafs-defrt  \
# Domain
# productionsite               1.0                  31.0           38.0
#
# Config          gc-mafs-defrt-sss  mafs-defrt  mafs-defrt-sss
# Domain
# productionsite               49.0        33.0            49.0

# %%
coverage[-1].T
# Out:
# Domain                productionsite
# Config
# blind-mafs-defrt                 2.0
# blind-mafs-defrt-sss            49.0
# gc-mafs-defrt                   39.0
# gc-mafs-defrt-sss               49.0
# mafs-defrt                      36.0
# mafs-defrt-sss                  48.0

# %%
# %matplotlib inline
coverage[0].plot.bar()

# %%
coverage
# Out:
# [Config       dmtg-def  dmtg-deft  dmtg-t100  dmtg-t100t  mafs-def  mafs-deft  \
#  Domain
#  blocksworld       0.0        1.0       16.0        16.0       0.0        0.0
#  depot             2.0        2.0        1.0         2.0       0.0        0.0
#  driverlog        15.0       15.0       20.0        20.0      15.0       17.0
#  elevators        12.0       14.0       17.0        15.0      15.0       13.0
#  logistics        15.0       16.0       20.0        17.0      12.0       14.0
#  rovers            9.0       10.0       20.0        20.0      18.0       18.0
#  satellites        9.0       10.0       20.0        20.0      17.0       20.0
#  sokoban           9.0        9.0        8.0        10.0       7.0        8.0
#  taxi             14.0       15.0       12.0        12.0       2.0        2.0
#  wireless          2.0        2.0        2.0         2.0       1.0        1.0
#  woodworking       7.0        6.0       13.0        13.0       6.0        4.0
#  zenotravel       17.0       18.0       18.0        20.0      14.0       16.0
#
#  Config       mafs-t100  mafs-t100t
#  Domain
#  blocksworld       18.0        18.0
#  depot              0.0         0.0
#  driverlog         20.0        20.0
#  elevators         13.0        14.0
#  logistics         15.0        14.0
#  rovers            20.0        20.0
#  satellites        20.0        20.0
#  sokoban            9.0         7.0
#  taxi               2.0         2.0
#  wireless           0.0         1.0
#  woodworking        6.0        11.0
#  zenotravel        20.0        20.0  ,
#  Config       dmtg-deft  dmtg-t100t  mafs-deft  mafs-t100t
#  Domain
#  blocksworld        1.0        18.0        0.0        16.0
#  depot              2.0         2.0        0.0         0.0
#  driverlog         16.0        20.0       15.0        16.0
#  elevators          8.0        15.0       15.0        15.0
#  logistics         15.0        16.0       15.0        17.0
#  rovers             8.0        20.0       17.0        17.0
#  satellites        11.0        20.0       19.0        20.0
#  sokoban            6.0        12.0        9.0         7.0
#  taxi              16.0        16.0        2.0         2.0
#  wireless           1.0         1.0        0.0         0.0
#  woodworking        9.0        15.0        3.0         7.0
#  zenotravel        19.0        20.0       15.0        20.0,
#  Config       dmtg-deft  dmtg-t100t  mafs-deft  mafs-t100t
#  Domain
#  blocksworld        0.0        17.0        0.0        16.0
#  depot              2.0         2.0        0.0         0.0
#  driverlog         16.0        20.0       14.0        14.0
#  elevators         15.0        15.0       17.0        15.0
#  logistics         16.0        17.0       12.0        15.0
#  rovers             8.0        20.0       18.0        18.0
#  satellites        10.0        20.0       20.0        20.0
#  sokoban            9.0         9.0        7.0         7.0
#  taxi              14.0        15.0        2.0         2.0
#  wireless           1.0         2.0        1.0         1.0
#  woodworking        7.0        13.0        2.0         7.0
#  zenotravel        19.0        20.0       16.0        19.0,
#  Config       dmtg-deft  dmtg-t100t  mafs-deft  mafs-t100t
#  Domain
#  blocksworld        0.0        19.0        0.0        18.0
#  depot              2.0         2.0        1.0         0.0
#  driverlog         15.0        20.0       14.0        16.0
#  elevators         14.0        13.0       16.0        15.0
#  logistics         18.0        18.0       13.0        16.0
#  rovers             9.0        20.0       17.0        19.0
#  satellites        10.0        20.0       19.0        20.0
#  sokoban            7.0         7.0        6.0         9.0
#  taxi              15.0        17.0        2.0         2.0
#  wireless           2.0         2.0        1.0         0.0
#  woodworking        7.0        14.0        3.0        10.0
#  zenotravel        19.0        20.0       14.0        19.0,
#  Config          blind-dmtg-deft  blind-dmtg-deft-sss  blind-mafs-defrt  \
#  Domain
#  blocksworld                 0.0                  0.0               0.0
#  depot                       0.0                  0.0               2.0
#  driverlog                   6.0                  7.0               7.0
#  elevators                   0.0                  0.0               3.0
#  logistics                   1.0                  0.0               3.0
#  productionsite              0.0                 20.0              20.0
#  rovers                      0.0                  0.0              20.0
#  satellites                  0.0                  0.0               3.0
#  sokoban                     6.0                  7.0               2.0
#  taxi                        2.0                  2.0               6.0
#  wireless                    0.0                  0.0               0.0
#  woodworking                 1.0                  1.0               2.0
#  zenotravel                  6.0                  5.0               5.0
#
#  Config          blind-mafs-defrt-sss  dmtg-deft  dmtg-deft-sss  gc-dmtg-deft  \
#  Domain
#  blocksworld                      0.0        1.0            0.0           1.0
#  depot                            2.0        1.0            2.0           2.0
#  driverlog                        7.0       17.0           16.0          17.0
#  elevators                        2.0       13.0           14.0          20.0
#  logistics                        3.0       18.0           11.0          17.0
#  productionsite                  20.0        0.0           20.0           0.0
#  rovers                          20.0        8.0            9.0          12.0
#  satellites                       3.0        8.0           10.0          14.0
#  sokoban                          0.0        8.0            7.0           6.0
#  taxi                             8.0       16.0           17.0          14.0
#  wireless                         0.0        2.0            2.0           0.0
#  woodworking                      1.0        8.0            1.0           2.0
#  zenotravel                       5.0       19.0           14.0          20.0
#
#  Config          gc-dmtg-deft-sss  gc-mafs-defrt  gc-mafs-defrt-sss  \
#  Domain
#  blocksworld                  1.0            1.0                1.0
#  depot                        2.0            6.0                4.0
#  driverlog                   16.0           17.0               16.0
#  elevators                   20.0           20.0               20.0
#  logistics                   13.0           18.0               14.0
#  productionsite              20.0           12.0               20.0
#  rovers                      12.0           19.0               20.0
#  satellites                  16.0           20.0               20.0
#  sokoban                      6.0            2.0                4.0
#  taxi                        13.0           11.0               13.0
#  wireless                     0.0            0.0                0.0
#  woodworking                  1.0            2.0                1.0
#  zenotravel                  16.0           20.0               16.0
#
#  Config          mafs-defrt  mafs-defrt-sss
#  Domain
#  blocksworld            0.0             1.0
#  depot                  0.0             0.0
#  driverlog             16.0            16.0
#  elevators             12.0            14.0
#  logistics             17.0            15.0
#  productionsite         6.0            20.0
#  rovers                20.0            18.0
#  satellites            20.0            19.0
#  sokoban                7.0             7.0
#  taxi                   2.0             2.0
#  wireless               2.0             1.0
#  woodworking            2.0             1.0
#  zenotravel            16.0            14.0  ,
#  Config          blind-mafs-defrt  blind-mafs-defrt-sss  gc-mafs-defrt  \
#  Domain
#  productionsite               2.0                  49.0           39.0
#
#  Config          gc-mafs-defrt-sss  mafs-defrt  mafs-defrt-sss
#  Domain
#  productionsite               49.0        36.0            48.0  ,
#  Config          blind-mafs-defrt  blind-mafs-defrt-sss  gc-mafs-defrt  \
#  Domain
#  productionsite               1.0                  31.0           38.0
#
#  Config          gc-mafs-defrt-sss  mafs-defrt  mafs-defrt-sss
#  Domain
#  productionsite               49.0        33.0            49.0  ]
